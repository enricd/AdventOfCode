# %%
with open("data_inputs/day12_input.txt") as file:
    data0 = file.read().splitlines()

data = """RRRRIICCFF
RRRRIICCCF
VVRRRCCFFF
VVRCCCJFFF
VVVVCJJCFE
VVIVCCJJEE
VVIIICJJEE
MIIIIIJJEE
MIIISIJEEE
MMMISSJEEE""".splitlines()

data
# Out:
# ['RRRRIICCFF',
#  'RRRRIICCCF',
#  'VVRRRCCFFF',
#  'VVRCCCJFFF',
#  'VVVVCJJCFE',
#  'VVIVCCJJEE',
#  'VVIIICJJEE',
#  'MIIIIIJJEE',
#  'MIIISIJEEE',
#  'MMMISSJEEE']

# %%
garden = [list(line) for line in data]

explored_plots = []
explored_regions = []
regions_perimeters = []

left = (0, -1)
right = (0, 1)
up = (-1, 0)
down = (1, 0)

for i in range(len(garden)):
    for j in range(len(garden[0])):
        if (i, j) not in explored_plots:
            explored_plots.append((i, j))
            curr_crop = garden[i][j]
            for dir in [left, up]:
                ni, nj = i+dir[0], j+dir[1]
                n_crop = garden[ni][nj]
                if n_crop == curr_crop:
                    if n_crop in explored_plots:
                        if n_crop in [reg[0] for reg in explored_regions]:
